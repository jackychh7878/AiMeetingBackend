# %%
import json
import pandas as pd
import requests

# URL to fetch JSON data
url = "https://spsvcprodsea.blob.core.windows.net/bestor-acc02701-cb45-42dc-9d32-2843911017ca/TranscriptionData/111e50ad-3703-421e-a6db-a0e5b0528992_0_0.json?skoid=d166f3aa-0128-4f75-bcea-0b5681081f33&sktid=33e01921-4d64-4f8c-a055-5bdaffd5e33d&skt=2025-03-11T08%3A53%3A41Z&ske=2025-03-16T08%3A58%3A41Z&sks=b&skv=2021-08-06&sv=2025-01-05&st=2025-03-11T08%3A53%3A41Z&se=2025-03-11T20%3A58%3A41Z&sr=b&sp=rl&sig=4mHIFIuR6uHh%2F1yVHDMGXv%2BniFNLrZKm3RYyT9Nev3U%3D"  # Replace with actual URL
response = requests.get(url)
json_data = response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\anaconda3\envs\TranscribingVideo\lib\site-packages\requests\models.py:963, in Response.json(self, **kwargs)
#     962 try:
# --> 963     return complexjson.loads(self.content.decode(encoding), **kwargs)
#     964 except UnicodeDecodeError:
#     965     # Wrong UTF codec detected; usually because it's not UTF-8
#     966     # but some other 8-bit codec.  This is an RFC violation,
#     967     # and the server didn't bother to tell us what codec *was*
#     968     # used.
#
# File ~\anaconda3\envs\TranscribingVideo\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
# ...

# %%
# Extracting speaker and text data
speaker_text_pairs = []
for phrase in json_data["recognizedPhrases"]:
    speaker = phrase["speaker"]
    display_text = phrase["nBest"][0]["display"]  # Taking the best recognized text
    speaker_text_pairs.append(f"Speaker-{speaker}: {display_text}")

# Creating a DataFrame
# df = pd.DataFrame(speaker_text_pairs, columns=["Speaker", "Text"])

# Grouping by Speaker and concatenating their texts
# df_grouped = df.groupby("Speaker")["Text"].apply(lambda x: " ".join(x)).reset_index()

# Converting to dictionary
# speaker_text_dict = dict(zip(df_grouped["Speaker"], df_grouped["Text"]))

# print(speaker_text_dict)

# %%
speaker_text_pairs
# Out:
# ['Speaker-1: OK OK，好咁樣呢就可以誒睇到個screen啦，就係講緊呢，就係一個客嘅要求，就係你即係咁樣嘅上for requirement啦。首先就係有個search嘅function嘅咁佢search翻佢SharePoint online，咁樣佢誒嗰堆document咧誒by實先實敗嘅keyword啦咁咩keyword咧咁可能誒下少少咧就會講到嘅咁同埋咧就search翻個days啦同埋誒呢個就好直覺啦就同埋咧就search for system嘅咁system係啲乜咧咁樣。',
#  'Speaker-1: 都係下邊咧，或者個spec嗰陣時咧就會講得清楚，啲嘅咁誒可能就go through咗第2個item先啦咁樣係咯咁就會講翻咧，就係佢個document咧，其實係誒會host埋呢個SharePoint online啦，同埋有時咧就會post for local file server同埋個local documentary system。',
#  'Speaker-1: 噉呢個就係一初頭個廊啦，就一個誒最基好似係佢個基本requirement，咁樣啦咁個detail啲係點樣嘅咧咁？首先咧，你可以幻想到咧，其實誒，馬會咧方面咧？就好多唔同嘅system嘅咁佢唔同嘅system咧之餘咧，就佢例如可能誒佢本system都會有啲誒，例如可能software啊咁樣啦咁所以佢咧有時誒有唔同嘅release啊有唔同嘅改變啊，又或者係每個system可能佢有啲conflict。',
#  'Speaker-1: 咁佢都想儲低呢堆咁嘅information嘅咁所以咧？就誒佢咧就嘗成一個system出嚟啦咁樣，就係去誒佢哋就可以去upload呢堆咁樣嘅information拜翻個system跟住咧亦都有個version control啦，同埋咧誒佢亦都呢個system咧會好翻翻唔同可能有啲custom feel嘅去儲翻咧去嚟關於呢個。',
#  'Speaker-1: 誒文件啊咁佢想要嘅additional information，例如可能呢份文件其實佢有同其他文件有個linkage㗎喎。',
# ...

# %%
import requests

def fetch_completed_transcription(url: str):
    response = requests.get(url)
    json_data = response.json()

    speaker_text_pairs = []
    for phrase in json_data["recognizedPhrases"]:
        speaker = phrase["speaker"]
        display_text = phrase["nBest"][0]["display"]  # Taking the best recognized text
        speaker_text_pairs.append(f"Speaker-{speaker}: {display_text}")
    return speaker_text_pairs

# %%
text_url = "https://spsvcprodsea.blob.core.windows.net/bestor-acc02701-cb45-42dc-9d32-2843911017ca/TranscriptionData/a3c0865a-542b-405c-ac2a-07d397744e33_0_0.json?skoid=d166f3aa-0128-4f75-bcea-0b5681081f33&sktid=33e01921-4d64-4f8c-a055-5bdaffd5e33d&skt=2025-03-11T08%3A20%3A57Z&ske=2025-03-16T08%3A25%3A57Z&sks=b&skv=2021-08-06&sv=2025-01-05&st=2025-03-11T08%3A20%3A57Z&se=2025-03-11T20%3A25%3A57Z&sr=b&sp=rl&sig=9J%2FGNufHXE4SjKpOOoRNTmeLdFuTOm6qKbkh7s1%2FsTc%3D"
result = fetch_completed_transcription(url=text_url)

# %%
result
# Out:
# ['Speaker-1: 好，嗱，上次我哋有第一round會啦，第一round我哋就應該誒睇過一啲design啦咁誒收咗一啲誒comments嘅咁一陣阿Sharon同小寶即係同阿Steve fun咧就會幫手去誒，講翻即係今次我哋誒收到上次comment之後咧就revise咗同埋propose咗多一啲design咁total有33個啦咁，第二咧就係知道嗰個誒，即係Canada就唔需要擺出嚟啦咁，第二就係要有下水啦咁，所以誒你你。',
#  'Speaker-1: 即係我之前佢send咗個design嗰度拎俾你哋，如果你哋有睇嘅話咧都見到誒，有翻個下水水喺度，咁今誒，今日呢個會完咗之後咧？期望可以誒，再收到你哋一啲feedback啦咁，如果誒嗰啲我哋都儘可能會會會睇下點樣執埋佢啦咁然之後我哋就會喺個PSE嗰個deck裏面咧，我哋就擺翻落去，讓我哋可以攞舉到一個誒。3個design出嚟喺個PSC會度俾同事去望下。',
#  'Speaker-1: 咁樣，咁呢個就係期望今日嗰個目標啦咁誒有冇補充先Raymond同阿dicky？',
#  'Speaker-1: 誒OK啦嚇咁樣就誒。我同阿dicky今朝都輪咗一輪，㗎啦嚇咁，我都誒阿dicky都幫咗我手集低咗啲comment嘅咁不如take誒，快啲手咁不如阿阿dicky講我哋嘅comment俾你聽啦，係咯嚇好啊，好啊好啊，因為我哋睇咗㗎啦嘛都係啦嚇好好噉唔該曬麻煩你吖。',
#  'Speaker-1: 係聽唔聽到大家係你好聽到係啦咁誒？首先逐個layout講先啦咁layout one先啦咁，其實有幾個point我哋睇到嘅第一樣嘢咧就係想上面Department嗰個electronic information嗰個manual咧就誒執翻即係誒，又睇下有冇啲特別啲嘅design啦，因為而家個樣比較平啲啊。',
#  'Speaker-1: 即係你見到佢哋全部都好似冇底啊，嗰啲咧就咁一個字咁樣咁睇下執唔執到啦呢個嚇？',
# ...

# %%
url = "https://southeastasia.api.cognitive.microsoft.com/speechtotext/v3.2-preview.2/transcriptions/111e50ad-3703-421e-a6db-a0e5b0528992"


headers = {
    "Ocp-Apim-Subscription-Key": os.getenv("AZURE_API_KEY"),  # Replace with your actual key
    "Content-Type": "application/json"
}

def check_status(url: str):
    response = requests.get(url, headers=headers)
    response.raise_for_status()  # Raises an error for bad responses
    json_data = response.json()

    transcribing_status = json_data.get("status", "")

    if transcribing_status == "Succeeded":
        file_url = json_data.get("links", {}).get("files")  # Avoids unnecessary empty string

        if file_url:
            content_response = requests.get(file_url, headers=headers)
            content_json = content_response.json()

            values = content_json.get("values", [])
            if values:
                content_url = values[0].get("links", {}).get("contentUrl")
                return content_url
    else:
        return "In Progress"

# %%
check_status(url)
# Out:
# 'https://spsvcprodsea.blob.core.windows.net/bestor-acc02701-cb45-42dc-9d32-2843911017ca/TranscriptionData/111e50ad-3703-421e-a6db-a0e5b0528992_0_0.json?skoid=d166f3aa-0128-4f75-bcea-0b5681081f33&sktid=33e01921-4d64-4f8c-a055-5bdaffd5e33d&skt=2025-03-11T16%3A34%3A35Z&ske=2025-03-16T16%3A39%3A35Z&sks=b&skv=2021-08-06&sv=2025-01-05&st=2025-03-11T16%3A34%3A35Z&se=2025-03-12T04%3A39%3A35Z&sr=b&sp=rl&sig=QBJ3BR2M4VbSnYKw5eLQcg1dNee681A3XNWus1%2BHpJQ%3D'

# %%
from dotenv import load_dotenv
import os
import requests

# Load environment variables
load_dotenv()

url = "https://southeastasia.api.cognitive.microsoft.com/speechtotext/v3.2-preview.2/transcriptions/111e50ad-3703-421e-a6db-a0e5b0528992"


headers = {
    "Ocp-Apim-Subscription-Key": os.getenv("AZURE_API_KEY"),  # Replace with your actual key
    "Content-Type": "application/json"
}
print(headers)

def check_status(url: str):
    response = requests.get(url, headers=headers)
    response.raise_for_status()  # Raises an error for bad responses
    json_data = response.json()

    transcribing_status = json_data.get("status", "")

    if transcribing_status == "Succeeded":
        file_url = json_data.get("links", {}).get("files")  # Avoids unnecessary empty string

        if file_url:
            content_response = requests.get(file_url, headers=headers)
            content_json = content_response.json()

            values = content_json.get("values", [])
            if values:
                content_url = values[0].get("links", {}).get("contentUrl")
                return content_url
    else:
        return "In Progress"

def fetch_completed_transcription(url: str):
    response = requests.get(url)
    response.raise_for_status()  # Raises an error for bad responses
    json_data = response.json()

    speaker_text_pairs = []
    for phrase in json_data.get("recognizedPhrases", []):
        speaker = phrase.get("speaker")
        display_text = phrase.get("nBest", [{}])[0].get("display", "")
        if speaker is not None and display_text:
            speaker_text_pairs.append(f"Speaker-{speaker}: {display_text}")
    return speaker_text_pairs

# %%
check_status(url)
# Out:
# 'https://spsvcprodsea.blob.core.windows.net/bestor-acc02701-cb45-42dc-9d32-2843911017ca/TranscriptionData/111e50ad-3703-421e-a6db-a0e5b0528992_0_0.json?skoid=d166f3aa-0128-4f75-bcea-0b5681081f33&sktid=33e01921-4d64-4f8c-a055-5bdaffd5e33d&skt=2025-03-12T14%3A02%3A32Z&ske=2025-03-17T14%3A07%3A32Z&sks=b&skv=2021-08-06&sv=2025-01-05&st=2025-03-12T14%3A02%3A32Z&se=2025-03-13T02%3A07%3A32Z&sr=b&sp=rl&sig=JnhcmNuYjhdH4d61rUYzJtPclvwlqf3lY7UdPO%2FxXPs%3D'

# %%
content_response = check_status(url)
if content_response != "In Progress":
    result = fetch_completed_transcription(content_response)
    print ({"transcriptions": result})
# else:
#     return {"transcriptions": "Transcription in progress"}
# Out:
# {'transcriptions': ['Speaker-1: OK OK，好咁樣呢就可以誒睇到個screen啦，就係講緊呢，就係一個客嘅要求，就係你即係咁樣嘅上for requirement啦。首先就係有個search嘅function嘅咁佢search翻佢SharePoint online，咁樣佢誒嗰堆document咧誒by實先實敗嘅keyword啦咁咩keyword咧咁可能誒下少少咧就會講到嘅咁同埋咧就search翻個days啦同埋誒呢個就好直覺啦就同埋咧就search for system嘅咁system係啲乜咧咁樣。', 'Speaker-1: 都係下邊咧，或者個spec嗰陣時咧就會講得清楚，啲嘅咁誒可能就go through咗第2個item先啦咁樣係咯咁就會講翻咧，就係佢個document咧，其實係誒會host埋呢個SharePoint online啦，同埋有時咧就會post for local file server同埋個local documentary system。', 'Speaker-1: 噉呢個就係一初頭個廊啦，就一個誒最基好似係佢個基本requirement，咁樣啦咁個detail啲係點樣嘅咧咁？首先咧，你可以幻想到咧，其實誒，馬會咧方面咧？就好多唔同嘅system嘅咁佢唔同嘅system咧之餘咧，就佢例如可能誒佢本system都會有啲誒，例如可能software啊咁樣啦咁所以佢咧有時誒有唔同嘅release啊有唔同嘅改變啊，又或者係每個system可能佢有啲conflict。', 'Speaker-1: 咁佢都想儲低呢堆咁嘅information嘅咁所以咧？就誒佢咧就嘗成一個system出嚟啦咁樣，就係去誒佢哋就可以去upload呢堆咁樣嘅information拜翻個system跟住咧亦都有個version control啦，同埋咧誒佢亦都呢個system咧會好翻翻唔同可能有啲custom feel嘅去儲翻咧去嚟關於呢個。', 'Speaker-1: 誒文件啊咁佢想要嘅additional information，例如可能呢份文件其實佢有同其他文件有個linkage㗎喎。', 'Speaker-1: 咁佢咧就會咧，係啦誒係拜個custom view咧去處理翻呢個linkage嘅，例如即係我係upload一個誒document一咁樣
# ...

# %%
headers = {
    "Ocp-Apim-Subscription-Key": os.getenv("AZURE_API_KEY"),  # Replace with your actual key
    "Content-Type": "application/json"
}

def check_status(url: str):
    response = requests.get(url, headers=headers)
    response.raise_for_status()  # Raises an error for bad responses
    json_data = response.json()

    transcribing_status = json_data.get("status", "")

    if transcribing_status == "Succeeded":
        file_url = json_data.get("links", {}).get("files")  # Avoids unnecessary empty string

        if file_url:
            content_response = requests.get(file_url, headers=headers)
            content_json = content_response.json()

            values = content_json.get("values", [])
            if values:
                response_url_list = []
                for item in values:
                    content_url = item.get("links", {}).get("contentUrl")
                    response_url_list.append(content_url)
                return response_url_list
    else:
        return "In Progress"

def fetch_completed_transcription(url: str):
    response = requests.get(url)
    response.raise_for_status()  # Raises an error for bad responses
    json_data = response.json()

    speaker_text_pairs = []
    for phrase in json_data.get("recognizedPhrases", []):
        speaker = phrase.get("speaker")
        display_text = phrase.get("nBest", [{}])[0].get("display", "")
        offset = phrase.get("offsetInTicks", 0) / 10000000  # Convert ticks to seconds
        duration = phrase.get("durationInTicks", 0) / 10000000  # Convert ticks to seconds

        start_time = format_time(offset)
        end_time = format_time(offset + duration)

        if speaker is not None and display_text:
            speaker_text_pairs.append(f"Speaker-{speaker} ({start_time} - {end_time}): {display_text}")
    return speaker_text_pairs


def format_time(seconds):
    minutes, seconds = divmod(int(seconds), 60)
    hours, minutes = divmod(minutes, 60)
    return f"{hours:02d}:{minutes:02d}:{seconds:02d}"

# %%
url = "https://southeastasia.api.cognitive.microsoft.com/speechtotext/v3.2-preview.2/transcriptions/93092441-5403-4b25-abeb-aff43272e16e"
content_url_list = check_status(url)

# %%
content_url_list
# Out:
# ['https://spsvcprodsea.blob.core.windows.net/bestor-acc02701-cb45-42dc-9d32-2843911017ca/TranscriptionData/93092441-5403-4b25-abeb-aff43272e16e_0_0.json?skoid=d166f3aa-0128-4f75-bcea-0b5681081f33&sktid=33e01921-4d64-4f8c-a055-5bdaffd5e33d&skt=2025-03-12T14%3A10%3A33Z&ske=2025-03-17T14%3A15%3A33Z&sks=b&skv=2021-08-06&sv=2025-01-05&st=2025-03-12T14%3A10%3A33Z&se=2025-03-13T02%3A15%3A33Z&sr=b&sp=rl&sig=TI0kXM14uS75aGz1cICXPbxBg5bMVS9XE0V72hjMLW0%3D',
#  'https://spsvcprodsea.blob.core.windows.net/bestor-acc02701-cb45-42dc-9d32-2843911017ca/TranscriptionData/93092441-5403-4b25-abeb-aff43272e16e_1_0.json?skoid=d166f3aa-0128-4f75-bcea-0b5681081f33&sktid=33e01921-4d64-4f8c-a055-5bdaffd5e33d&skt=2025-03-12T14%3A10%3A33Z&ske=2025-03-17T14%3A15%3A33Z&sks=b&skv=2021-08-06&sv=2025-01-05&st=2025-03-12T14%3A10%3A33Z&se=2025-03-13T02%3A15%3A33Z&sr=b&sp=rl&sig=f2gN41Lr2iwxHGE8LIMtQGpi4GGobdRfvOzeXg630KY%3D',
# ...

# %%
output_list = []
for content_url in content_url_list:
    result = fetch_completed_transcription(content_url)
    result_dict = {"transcriptions": result}
    output_list.append(result_dict)

# %%
output_list

# %%
import requests
import base64
import os
from pydub import AudioSegment

# Function to download MP4 file
import requests
import base64
import os
from pydub import AudioSegment

def mp4_to_base64(mp4_url):
    """
    Downloads an MP4 file from a URL, extracts the audio, converts it to WAV, and returns a base64-encoded string.
    """
    try:
        # Define temporary file paths
        mp4_path = "temp_audio.mp4"
        wav_path = "temp_audio.wav"

        # Step 1: Download MP4
        response = requests.get(mp4_url, stream=True)
        if response.status_code == 200:
            with open(mp4_path, "wb") as file:
                for chunk in response.iter_content(chunk_size=1024):
                    file.write(chunk)
            print("Downloaded MP4")
        else:
            raise Exception(f"Failed to download MP4. Status code: {response.status_code}")

        # Step 2: Convert MP4 to WAV
        audio = AudioSegment.from_file(mp4_path, format="mp4")
        audio.export(wav_path, format="wav")
        print("Converted to WAV")

        # Step 3: Encode WAV to base64
        with open(wav_path, "rb") as audio_file:
            encoded_audio = base64.b64encode(audio_file.read()).decode("utf-8")

        # Cleanup temporary files
        os.remove(mp4_path)
        os.remove(wav_path)

        return encoded_audio  # Return the base64-encoded string

    except Exception as e:
        print(f"Error: {e}")
        return None


# Function to call Speech-to-Text API
def call_speech_to_text_api(api_url, api_key, audio_base64):
    headers = {"Authorization": f"Bearer {api_key}", "Content-Type": "application/json"}
    payload = {
      "config": {
        "languageCode": "yue",
        "maxAlternatives": 2,
        "enableSeparateRecognitionPerChannel": False,
        "enableAutomaticPunctuation": True
        },
        "enableWordTimeOffsets": True,
        "diarizationConfig": {
            "disableSpeakerDiarization": False
        },
        "audio": {
            "content": audio_base64
        }
    }
    response = requests.post(api_url, json=payload, headers=headers)
    return response.json()

# %%
mp4_url = "https://catomindst.blob.core.windows.net/meeting/VTC%20Hospitality%20_%20HTI%20_%20CCI%20_%20ICI%20_%20IVE-HT%20_%20Portal%20Design%20Discussion/VTC%20Hospitality%20_%20HTI%20_%20CCI%20_%20ICI%20_%20IVE-HT%20_%20Portal%20Design%20Discussion-20250116_155012-Meeting%20Recording.mp4?sv=2023-01-03&st=2025-03-16T08%3A01%3A50Z&se=2025-03-17T08%3A01%3A50Z&sr=b&sp=r&sig=9axOyybUzjj4c7VhnbYxxh%2B1CTlgk25oOUkBS%2BxCEYA%3D" # Replace with actual URL
api_url = "https://portal-demo.fano.ai/speech/long-running-recognize"  # Replace with actual API endpoint
api_key = os.getenv("FANOLAB_API_KEY")  # Replace with your actual API key

# Download and process audio
audio_base64 = mp4_to_base64(mp4_url)

audio_base64

# %%
# Call API
response = call_speech_to_text_api(api_url, api_key, audio_base64)
print("API Response:", response)
# Out:
# API Response: {'code': 413, 'message': 'request entity too large'}

# %%
# Cleanup temporary files
os.remove(mp4_path)
os.remove(wav_path)

# %%
import os
from dotenv import load_dotenv
from flask import Flask, request, jsonify, send_from_directory
import requests
from pydub import AudioSegment

# Load environment variables
load_dotenv()

def call_speech_to_text_api():
    """
    Receives a JSON request with an MP4 URL, converts it to WAV, and sends the file URL to FanoLab API.
    """

    # Generate the file URL
    file_url = f"./uploads/audio.wav"  # Replace with actual domain if hosted

    # Prepare API request
    FANOLAB_API_KEY = os.getenv("FANOLAB_API_KEY")
    headers = {"Authorization": f"Bearer {FANOLAB_API_KEY}", "Content-Type": "application/json"}
    payload = {
        "config": {
            "languageCode": "yue",
            "maxAlternatives": 2,
            "enableSeparateRecognitionPerChannel": False,
            "enableAutomaticPunctuation": True
        },
        "enableWordTimeOffsets": True,
        "diarizationConfig": {
            "disableSpeakerDiarization": False
        },
        "audio": {
            "uri": file_url  # Using URL instead of base64 content
        }
    }

    # Send request to FanoLab API
    response = requests.post("https://portal-demo.fano.ai/speech/long-running-recognize", json=payload, headers=headers)

    return response.json()

# %%
call_speech_to_text_api()
# Out:
# {'name': '4b1d21a4-637b-46cb-b605-57e40b78e383',
#  'metadata': None,
#  'done': False}
